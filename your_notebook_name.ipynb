# %%
from google.colab import drive
 drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
fname='/content/drive/MyDrive/CodingDojo/04-DataEnrichment/Week15/Data/data (4) (1).csv'
df = pd.read_csv(fname)
df.info()
df.head()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import missingno as msno

# %%
fname='/content/drive/MyDrive/CodingDojo/04-DataEnrichment/Week15/Data/data (4) (1).csv'
df = pd.read_csv(fname)
df.info()
df.head()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import missingno as msno
import seaborn as sns
import numpy as np

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import missingno as msno
import seaborn as sns
import numpy as np

# %%
fname='/content/drive/MyDrive/CodingDojo/04-DataEnrichment/Week15/Data/data (4) (1).csv'
df = pd.read_csv(fname)
df.info()
df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
# Assuming your data file is named 'medical_data.csv'
df = pd.read_csv('medical_data.csv')

# Display the first few rows of the DataFrame
print(df.head())

# Plotting histogram with KDE for specified features
plt.figure(figsize=(12, 8))

# Features to analyze
features = ['VitD_levels', 'Doc_visits', 'TotalCharge']

for feature in features:
    plt.subplot(2, 2, features.index(feature) + 1)
    sns.histplot(df[feature], kde=True, color='skyblue', bins=30)

    # Add lines for mean, median, and +/- 1 std
    mean_val = df[feature].mean()
    median_val = df[feature].median()
    std_val = df[feature].std()

    plt.axvline(mean_val, color='red', linestyle='dashed', linewidth=2, label='Mean')
    plt.axvline(median_val, color='green', linestyle='dashed', linewidth=2, label='Median')
    plt.axvline(mean_val + std_val, color='black', linestyle='dashed', linewidth=2, label='+1 Std')
    plt.axvline(mean_val - std_val, color='black', linestyle='dashed', linewidth=2, label='-1 Std')

    # Highlight the range between +1 and -1 std
    plt.axvspan(mean_val - std_val, mean_val + std_val, color='yellow', alpha=0.3, label='+/- 1 Std Range')

    # Set plot labels and title
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.title(f'Histogram with KDE for {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Plotting histogram with KDE for specified features
plt.figure(figsize=(12, 8))

# Features to analyze
features = ['VitD_levels', 'Doc_visits', 'TotalCharge']

for feature in features:
    plt.subplot(2, 2, features.index(feature) + 1)
    sns.histplot(df[feature], kde=True, color='skyblue', bins=30)

    # Add lines for mean, median, and +/- 1 std
    mean_val = df[feature].mean()
    median_val = df[feature].median()
    std_val = df[feature].std()

    plt.axvline(mean_val, color='red', linestyle='dashed', linewidth=2, label='Mean')
    plt.axvline(median_val, color='green', linestyle='dashed', linewidth=2, label='Median')
    plt.axvline(mean_val + std_val, color='black', linestyle='dashed', linewidth=2, label='+1 Std')
    plt.axvline(mean_val - std_val, color='black', linestyle='dashed', linewidth=2, label='-1 Std')

    # Highlight the range between +1 and -1 std
    plt.axvspan(mean_val - std_val, mean_val + std_val, color='yellow', alpha=0.3, label='+/- 1 Std Range')

    # Set plot labels and title
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.title(f'Histogram with KDE for {feature}')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# Descriptive statistics for each feature
for feature in features:
    print(f"\nDescriptive Statistics for {feature}:")
    print(df[feature].describe())

    # Check skewness
    skewness = df[feature].skew()
    print(f"Skewness: {skewness}")

    # Check kurtosis
    kurtosis = df[feature].kurtosis()
    print(f"Kurtosis: {kurtosis}")

    print("\n" + "-" * 40)

# Additional analysis or visualizations can be added based on these findings.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Features to analyze
features = ['VitD_levels', 'Doc_visits', 'TotalCharge']

# Set the style for the plots
sns.set(style="whitegrid")

# Plot histograms with kde and add lines for mean, median, +1 std, -1 std
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[feature], kde=True, color='blue', bins=30)

    # Add lines for mean, median, +1 std, -1 std
    plt.axvline(df[feature].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
    plt.axvline(df[feature].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
    plt.axvline(df[feature].mean() + df[feature].std(), color='black', linestyle='dashed', linewidth=2, label='+1 Std')
    plt.axvline(df[feature].mean() - df[feature].std(), color='black', linestyle='dashed', linewidth=2, label='-1 Std')

    # Highlight the range between +1 and -1 std
    plt.axvspan(df[feature].mean() - df[feature].std(), df[feature].mean() + df[feature].std(), color='yellow', alpha=0.3, label='±1 Std Range')

    # Set plot labels and title
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {feature}')
    
    # Show legend
    plt.legend()

    # Show the plot
    plt.show()

    # Answer the questions
    print(f"\nAnalysis for {feature}:")
    print(f"Is it Discrete or Continuous? {['Continuous', 'Discrete'][df[feature].nunique() <= 10]}")
    print(f"Does it have a skew? If so, which direction (+/-): {['No skew', 'Positive skew', 'Negative skew'][np.sign(df[feature].skew()) + 1]}")
    print(f"What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic): {['Mesokurtic', 'Leptokurtic', 'Platykurtic'][np.sign(df[feature].kurtosis()) + 1]}")
    print("\n" + "=" * 50 + "\n")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Features to analyze
features = ['VitD_levels', 'Doc_visits', 'TotalCharge']

# Set the style for the plots
sns.set(style="whitegrid")

# Plot histograms with kde and add lines for mean, median, +1 std, -1 std
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[feature], kde=True, color='blue', bins=30)

    # Add lines for mean, median, +1 std, -1 std
    plt.axvline(df[feature].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
    plt.axvline(df[feature].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
    plt.axvline(df[feature].mean() + df[feature].std(), color='black', linestyle='dashed', linewidth=2, label='+1 Std')
    plt.axvline(df[feature].mean() - df[feature].std(), color='black', linestyle='dashed', linewidth=2, label='-1 Std')

    # Highlight the range between +1 and -1 std
    plt.axvspan(df[feature].mean() - df[feature].std(), df[feature].mean() + df[feature].std(), color='yellow', alpha=0.3, label='±1 Std Range')

    # Set plot labels and title
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {feature}')
    
    # Show legend
    plt.legend()

    # Show the plot
    plt.show()
    
# Answer the questions
print(f"\nAnalysis for {feature}:")
print(f"Is it Discrete or Continuous? {['Continuous', 'Discrete'][df[feature].nunique() <= 10]}")

# Check skewness
skewness = df[feature].skew()
skewness_direction = 'No skew' if skewness == 0 else ('Positive skew' if skewness > 0 else 'Negative skew')
print(f"Does it have a skew? If so, which direction (+/-): {skewness_direction}")

# Check kurtosis
kurtosis = df[feature].kurtosis()
kurtosis_type = 'Mesokurtic' if kurtosis == 0 else ('Leptokurtic' if kurtosis > 0 else 'Platykurtic')
print(f"What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic): {kurtosis_type}")

print("\n" + "=" * 50 + "\n")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure and axes
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# Plot the histogram with KDE for VitD_levels
sns.histplot(df['VitD_levels'], kde=True, color='skyblue', ax=axes[0])
axes[0].axvline(df['VitD_levels'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
axes[0].axvline(df['VitD_levels'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
axes[0].axvline(df['VitD_levels'].mean() + df['VitD_levels'].std(), color='black', linestyle='dashed', linewidth=2, label='+1 std')
axes[0].axvline(df['VitD_levels'].mean() - df['VitD_levels'].std(), color='black', linestyle='dashed', linewidth=2, label='-1 std')
axes[0].axvspan(df['VitD_levels'].mean() - df['VitD_levels'].std(), df['VitD_levels'].mean() + df['VitD_levels'].std(), color='yellow', alpha=0.3, label='±1 std')
axes[0].set_title('Histogram for VitD_levels')
axes[0].legend()

# Plot the histogram with KDE for Doc_visits
sns.histplot(df['Doc_visits'], kde=True, color='lightcoral', ax=axes[1])
axes[1].axvline(df['Doc_visits'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
axes[1].axvline(df['Doc_visits'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
axes[1].axvline(df['Doc_visits'].mean() + df['Doc_visits'].std(), color='black', linestyle='dashed', linewidth=2, label='+1 std')
axes[1].axvline(df['Doc_visits'].mean() - df['Doc_visits'].std(), color='black', linestyle='dashed', linewidth=2, label='-1 std')
axes[1].axvspan(df['Doc_visits'].mean() - df['Doc_visits'].std(), df['Doc_visits'].mean() + df['Doc_visits'].std(), color='yellow', alpha=0.3, label='±1 std')
axes[1].set_title('Histogram for Doc_visits')
axes[1].legend()

# Plot the histogram with KDE for TotalCharge
sns.histplot(df['TotalCharge'], kde=True, color='lightgreen', ax=axes[2])
axes[2].axvline(df['TotalCharge'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
axes[2].axvline(df['TotalCharge'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
axes[2].axvline(df['TotalCharge'].mean() + df['TotalCharge'].std(), color='black', linestyle='dashed', linewidth=2, label='+1 std')
axes[2].axvline(df['TotalCharge'].mean() - df['TotalCharge'].std(), color='black', linestyle='dashed', linewidth=2, label='-1 std')
axes[2].axvspan(df['TotalCharge'].mean() - df['TotalCharge'].std(), df['TotalCharge'].mean() + df['TotalCharge'].std(), color='yellow', alpha=0.3, label='±1 std')
axes[2].set_title('Histogram for TotalCharge')
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
VitD_levels:

Discrete or Continuous: Continuous
Skew: Check if the distribution is skewed (positive or negative).
Kurtosis: Check the kurtosis of the distribution.
Doc_visits:

Discrete or Continuous: Discrete (as it represents the number of doctor visits).
Skew: Check if the distribution is skewed (positive or negative).
Kurtosis: Check the kurtosis of the distribution.
TotalCharge:

Discrete or Continuous: Continuous
Skew: Check if the distribution is skewed (positive or negative).
Kurtosis: Check the kurtosis of the distribution.
Now, let's proceed to examine each of these aspects:

python
Copy code
# Descriptive statistics for each feature
for feature in features:
    print(f"\nDescriptive Statistics for {feature}:")
    print(df[feature].describe())

    # Check skewness
    skewness = df[feature].skew()
    print(f"Skewness: {skewness}")

    # Check kurtosis
    kurtosis = df[feature].kurtosis()
    print(f"Kurtosis: {kurtosis}")

    print("\n" + "-" * 40)

# Additional analysis or visualizations can be added based on these findings.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure and axes
fig, axes = plt.subplots(3, 1, figsize=(10, 15))

# Plot the histogram with KDE for VitD_levels
sns.histplot(df['VitD_levels'], kde=True, color='skyblue', ax=axes[0])
axes[0].axvline(df['VitD_levels'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
axes[0].axvline(df['VitD_levels'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
axes[0].axvline(df['VitD_levels'].mean() + df['VitD_levels'].std(), color='black', linestyle='dashed', linewidth=2, label='+1 std')
axes[0].axvline(df['VitD_levels'].mean() - df['VitD_levels'].std(), color='black', linestyle='dashed', linewidth=2, label='-1 std')
axes[0].axvspan(df['VitD_levels'].mean() - df['VitD_levels'].std(), df['VitD_levels'].mean() + df['VitD_levels'].std(), color='yellow', alpha=0.3, label='±1 std')
axes[0].set_title('Histogram for VitD_levels')
axes[0].legend()

# Plot the histogram with KDE for Doc_visits
sns.histplot(df['Doc_visits'], kde=True, color='lightcoral', ax=axes[1])
axes[1].axvline(df['Doc_visits'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
axes[1].axvline(df['Doc_visits'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
axes[1].axvline(df['Doc_visits'].mean() + df['Doc_visits'].std(), color='black', linestyle='dashed', linewidth=2, label='+1 std')
axes[1].axvline(df['Doc_visits'].mean() - df['Doc_visits'].std(), color='black', linestyle='dashed', linewidth=2, label='-1 std')
axes[1].axvspan(df['Doc_visits'].mean() - df['Doc_visits'].std(), df['Doc_visits'].mean() + df['Doc_visits'].std(), color='yellow', alpha=0.3, label='±1 std')
axes[1].set_title('Histogram for Doc_visits')
axes[1].legend()

# Plot the histogram with KDE for TotalCharge
sns.histplot(df['TotalCharge'], kde=True, color='lightgreen', ax=axes[2])
axes[2].axvline(df['TotalCharge'].mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
axes[2].axvline(df['TotalCharge'].median(), color='green', linestyle='dashed', linewidth=2, label='Median')
axes[2].axvline(df['TotalCharge'].mean() + df['TotalCharge'].std(), color='black', linestyle='dashed', linewidth=2, label='+1 std')
axes[2].axvline(df['TotalCharge'].mean() - df['TotalCharge'].std(), color='black', linestyle='dashed', linewidth=2, label='-1 std')
axes[2].axvspan(df['TotalCharge'].mean() - df['TotalCharge'].std(), df['TotalCharge'].mean() + df['TotalCharge'].std(), color='yellow', alpha=0.3, label='±1 std')
axes[2].set_title('Histogram for TotalCharge')
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
# Descriptive statistics for each feature
for feature in ['VitD_levels', 'Doc_visits', 'TotalCharge']:
    print(f"\nDescriptive Statistics for {feature}:")
    print(df[feature].describe())

    # Check skewness
    skewness = df[feature].skew()
    print(f"Skewness: {skewness}")

    # Check kurtosis
    kurtosis = df[feature].kurtosis()
    print(f"Kurtosis: {kurtosis}")

    print("\n" + "-" * 40)

# %%
# Analysis for each feature
for feature in ['VitD_levels', 'Doc_visits', 'TotalCharge']:
    print(f"\nAnalysis for {feature}:")
    print(f"Is it Discrete or Continuous? {['Continuous', 'Discrete'][df[feature].nunique() <= 10]}")
    print(f"Does it have a skew? If so, which direction (+/-): {['No skew', 'Positive skew', 'Negative skew'][np.sign(df[feature].skew()) + 1]}")
    print(f"What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic): {['Mesokurtic', 'Leptokurtic', 'Platykurtic'][np.sign(df[feature].kurtosis()) + 1]}")
    print("\n" + "=" * 50 + "\n")

# %%
# Analysis for each feature
for feature in ['VitD_levels', 'Doc_visits', 'TotalCharge']:
    print(f"\nAnalysis for {feature}:")
    
    # Check if it's Discrete or Continuous
    discrete_continuous = ['Continuous', 'Discrete'][df[feature].nunique() <= 10]
    print(f"Is it Discrete or Continuous? {discrete_continuous}")
    
    # Check skewness
    skewness = df[feature].skew()
    skew_direction = ['No skew', 'Positive skew', 'Negative skew'][np.sign(skewness) + 1]
    print(f"Does it have a skew? If so, which direction (+/-): {skew_direction}")
    
    # Check kurtosis
    kurtosis = df[feature].kurtosis()
    kurtosis_type = ['Mesokurtic', 'Leptokurtic', 'Platykurtic'][np.sign(kurtosis) + 1]
    print(f"What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic): {kurtosis_type}")
    
    print("\n" + "=" * 50 + "\n")

# %%
# Analysis for each feature
for feature in ['VitD_levels', 'Doc_visits', 'TotalCharge']:
    print(f"\nAnalysis for {feature}:")
    
    # Check if it's Discrete or Continuous
    discrete_continuous = ['Continuous', 'Discrete'][df[feature].nunique() <= 10]
    print(f"Is it Discrete or Continuous? {discrete_continuous}")
    
    # Check skewness
    skewness = df[feature].skew()
    skew_direction = ['No skew', 'Positive skew', 'Negative skew'][1 if skewness > 0 else 2 if skewness < 0 else 0]
    print(f"Does it have a skew? If so, which direction (+/-): {skew_direction}")
    
    # Check kurtosis
    kurtosis = df[feature].kurtosis()
    kurtosis_type = ['Mesokurtic', 'Leptokurtic', 'Platykurtic'][np.sign(kurtosis) + 1]
    print(f"What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic): {kurtosis_type}")
    
    print("\n" + "=" * 50 + "\n")

# %%
import numpy as np

# Analysis for each feature
for feature in ['VitD_levels', 'Doc_visits', 'TotalCharge']:
    print(f"\nAnalysis for {feature}:")
    
    # Check if it's Discrete or Continuous
    discrete_continuous = ['Continuous', 'Discrete'][df[feature].nunique() <= 10]
    print(f"Is it Discrete or Continuous? {discrete_continuous}")
    
    # Check skewness
    skewness = df[feature].skew()
    skew_direction = ['No skew', 'Positive skew', 'Negative skew'][1 if skewness > 0 else 2 if skewness < 0 else 0]
    print(f"Does it have a skew? If so, which direction (+/-): {skew_direction}")
    
    # Check kurtosis
    kurtosis = df[feature].kurtosis()
    kurtosis_type = ['Mesokurtic', 'Leptokurtic', 'Platykurtic'][1 if kurtosis > 0 else 2 if kurtosis < 0 else 0]
    print(f"What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic): {kurtosis_type}")
    
    print("\n" + "=" * 50 + "\n")

# %%
from google.colab import files

# Specify the path to the Downloads folder
downloads_path = '/content/downloads/'

# Create the folder if it doesn't exist
# !mkdir -p "{downloads_path}"

# Save and download the notebook to the Downloads folder
file_path = f"{downloads_path}your_notebook_name.ipynb"
files.download(file_path)

# %%
from google.colab import files

# Specify the path to the Downloads folder
downloads_path = '/content/downloads/'

# Create the folder if it doesn't exist
# !mkdir -p "{downloads_path}"

# Save and download the notebook to the Downloads folder
file_path = f"{downloads_path}your_notebook_name.ipynb"
files.download(file_path)

# %%
from google.colab import files

# Save the notebook with a specific name
notebook_name = "your_notebook_name.ipynb"
# %notebook -r -f $notebook_name

# Download the notebook
files.download(notebook_name)
